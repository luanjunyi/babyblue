# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('/Users/jerry_luan/codebase/private/babyblue')
import pandas as pd
from graph import build_candles, draw, config
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
FILE = "/Users/jerry_luan/Downloads/002730.csv"
FRAME = 10 # frame in seconds 

# data source config, the colume label for price, volume and time
PRICE = "Price"
VOLUME = "Volume"
TIME = "Time"
config(PRICE, VOLUME, TIME)

# %%
# %pdb
# Out:
# Automatic pdb calling has been turned ON

# %%
data = pd.read_csv(FILE)
candles = build_candles(data, FRAME)

# %%
draw(candles)
# Out:
# This is the format of your plot grid:
# [ (1,1) x1,y1 ]
# [ (2,1) x1,y2 ]
# ...
